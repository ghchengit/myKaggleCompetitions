# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
train_df = pd.read_csv("train.csv", sep=",")
test_df = pd.read_csv("test.csv", sep=",")
combined_data = [train_df, test_df]

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train_df.describe(include=[np.object])
# Out:
#                                      Name   Sex  Ticket    Cabin Embarked
# count                                 891   891     891      204      889
# unique                                891     2     681      147        3
# top     Andersson, Miss. Sigrid Elisabeth  male  347082  B96 B98        S
# freq                                    1   577       7        4      644

# %%
train_df[['Pclass', 'Survived']].groupby(['Pclass']).mean().sort_values('Survived', ascending=False)
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
train_df[['Sex', 'Survived']].groupby(['Sex']).mean().sort_values('Survived', ascending=False)
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
train_df[['SibSp', 'Survived']].groupby(['SibSp']).agg(['mean', 'count']).sort_values(('Survived', 'mean'), ascending=False)
# Out:
#        Survived
#            mean count
# SibSp
# 1      0.535885   209
# 2      0.464286    28
# 0      0.345395   608
# 3      0.250000    16
# 4      0.166667    18
# 5      0.000000     5
# 8      0.000000     7

# %%
train_df[['Parch', 'Survived']].groupby(['Parch']).agg(['mean', 'count']).sort_values(('Survived', 'mean'), ascending=False)
# Out:
#        Survived
#            mean count
# Parch
# 3      0.600000     5
# 1      0.550847   118
# 2      0.500000    80
# 0      0.343658   678
# 5      0.200000     5
# 4      0.000000     4
# 6      0.000000     1

# %%
g = sns.FacetGrid(train_df, col='Survived')
g.map(sns.distplot, 'Age', bins=20)

# %%
g = sns.FacetGrid(train_df, col='Survived', row='Pclass', height=2.5, aspect=1.5)
g.map(sns.distplot, 'Age', bins=20, kde=False)

# %%
sns.catplot(x='Pclass', y='Survived', hue='Sex', 
            row='Embarked', kind='point', height=3, aspect=1.5,
            data=train_df)

# %%
#drop columns
train_df.drop(['PassengerId', 'Cabin', 'Ticket'], axis=1, inplace=True)

for dataset in combined_data:
    #completing
    dataset['Age'].fillna(dataset['Age'].median(), inplace=True)
    dataset['Embarked'].fillna(dataset['Embarked'].mode()[0], inplace=True)
    dataset['Fare'].fillna(dataset['Fare'].median(), inplace=True)
    
    #creating
    dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] + 1
    dataset['IsAlone'] = 1
    dataset.loc[dataset['FamilySize'] > 1, 'IsAlone'] = 0
    dataset['Title'] = dataset['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
    
    dataset['FareBin'] = pd.cut(dataset['Fare'], 4)
    dataset['AgeBin'] = pd.cut(dataset['Age'].astype(int), 5)
    
train_df.sample(10)
# Out:
#      Survived  Pclass                                               Name  \
# 126         0       3                                McMahon, Mr. Martin
# 600         1       2  Jacobsohn, Mrs. Sidney Samuel (Amy Frances Chr...
# 518         1       2  Angle, Mrs. William A (Florence "Mary" Agnes H...
# 741         0       1                      Cavendish, Mr. Tyrell William
# 670         1       2  Brown, Mrs. Thomas William Solomon (Elizabeth ...
# 551         0       2                        Sharp, Mr. Percival James R
# 389         1       2                              Lehmann, Miss. Bertha
# 347         1       3          Davison, Mrs. Thomas Henry (Mary E Finck)
# 542         0       3                  Andersson, Miss. Sigrid Elisabeth
# 437         1       2              Richards, Mrs. Sidney (Emily Hocking)
#
#         Sex   Age  SibSp  Parch    Fare Embarked  FamilySize  IsAlone Title  \
# 126    male  28.0      0      0   7.750        Q           1        1    Mr
# 600  female  24.0      2      1  27.000        S           4        0   Mrs
# 518  female  36.0      1      0  26.000        S           2        0   Mrs
# 741    male  36.0      1      0  78.850        S           2        0    Mr
# 670  female  40.0      1      1  39.000        S           3        0   Mrs
# 551    male  27.0      0      0  26.000        S           1        1    Mr
# 389  female  17.0      0      0  12.000        C           1        1  Miss
# 347  female  28.0      1      0  16.100        S           2        0   Mrs
# 542  female  11.0      4      2  31.275        S           7        0  Miss
# 437  female  24.0      2      3  18.750        S           6        0   Mrs
#
#                FareBin         AgeBin
# 126  (-0.512, 128.082]   (16.0, 32.0]
# 600  (-0.512, 128.082]   (16.0, 32.0]
# 518  (-0.512, 128.082]   (32.0, 48.0]
# 741  (-0.512, 128.082]   (32.0, 48.0]
# 670  (-0.512, 128.082]   (32.0, 48.0]
# 551  (-0.512, 128.082]   (16.0, 32.0]
# 389  (-0.512, 128.082]   (16.0, 32.0]
# 347  (-0.512, 128.082]   (16.0, 32.0]
# 542  (-0.512, 128.082]  (-0.08, 16.0]
# 437  (-0.512, 128.082]   (16.0, 32.0]

# %%
pd.crosstab(train_df['Title'], train_df['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
for dataset in combined_data:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col', \
        'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')

    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')
    
train_df[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4    Rare  0.347826

# %%
title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5}
for dataset in combined_data:
    dataset['Title'] = dataset['Title'].map(title_mapping)
    dataset['Title'] = dataset['Title'].fillna(0)
    
train_df.sample(5)
# Out:
#      Survived  Pclass                                               Name  \
# 53          1       2  Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...
# 764         0       3                             Eklund, Mr. Hans Linus
# 106         1       3                   Salkjelsvik, Miss. Anna Kristine
# 620         0       3                                Yasbeck, Mr. Antoni
# 38          0       3                 Vander Planke, Miss. Augusta Maria
#
#         Sex   Age  SibSp  Parch     Fare Embarked  FamilySize  IsAlone  Title  \
# 53   female  29.0      1      0  26.0000        S           2        0      3
# 764    male  16.0      0      0   7.7750        S           1        1      1
# 106  female  21.0      0      0   7.6500        S           1        1      2
# 620    male  27.0      1      0  14.4542        C           2        0      1
# 38   female  18.0      2      0  18.0000        S           3        0      2
#
#                FareBin         AgeBin
# 53   (-0.512, 128.082]   (16.0, 32.0]
# 764  (-0.512, 128.082]  (-0.08, 16.0]
# 106  (-0.512, 128.082]   (16.0, 32.0]
# 620  (-0.512, 128.082]   (16.0, 32.0]
# 38   (-0.512, 128.082]   (16.0, 32.0]
